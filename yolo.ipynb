# %%
from ultralytics import YOLO
import cv2

# %%
from ultralytics import YOLO
import cv2
model = YOLO('yolov8n.pt')

# %%
# Inference
results = model('./2.jpg',stream=True,show=True)

# Results
cv2.waitKey(0)
# Out:
# -1

# %%
for x in results:
    print(x.boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0., 0., 0., 9., 0., 0., 0., 9.])
# conf: tensor([0.8459, 0.8092, 0.8062, 0.7769, 0.7610, 0.7295, 0.7046, 0.4020, 0.3432])
# data: tensor([[1.9306e+02, 2.1719e+02, 2.5654e+02, 4.4331e+02, 8.4591e-01, 0.0000e+00],
#         [4.6747e-01, 2.0938e+02, 2.9297e+01, 3.0879e+02, 8.0921e-01, 0.0000e+00],
#         [1.5158e+02, 2.1398e+02, 2.0178e+02, 3.8998e+02, 8.0624e-01, 0.0000e+00],
#         [1.1228e+02, 2.2720e+02, 1.6210e+02, 4.0201e+02, 7.7688e-01, 0.0000e+00],
#         [2.2230e+02, 1.9268e+00, 2.6676e+02, 1.3446e+02, 7.6099e-01, 9.0000e+00],
#         [7.2984e+01, 2.3639e+02, 1.2095e+02, 3.9761e+02, 7.2945e-01, 0.0000e+00],
#         [2.7094e+01, 2.0879e+02, 5.4918e+01, 3.0311e+02, 7.0458e-01, 0.0000e+00],
#         [1.0119e+02, 2.2671e+02, 1.2070e+02, 2.7235e+02, 4.0202e-01, 0.0000e+00],
#         [1.7893e+02, 6.2228e+01, 2.1255e+02, 1.4252e+02, 3.4318e-01, 9.0000e+00]])
# id: None
# is_track: False
# orig_shape: (512, 320)
# shape: torch.Size([9, 6])
# xywh: tensor([[224.8000, 330.2465,  63.4783, 226.1199],
#         [ 14.8823, 259.0851,  28.8297,  99.4163],
#         [176.6826, 301.9797,  50.2039, 176.0014],
#         [137.1879, 314.6030,  49.8214, 174.8121],
#         [244.5272,  68.1936,  44.4624, 132.5337],
#         [ 96.9658, 316.9995,  47.9629, 161.2236],
#         [ 41.0057, 255.9483,  27.8236,  94.3193],
#         [110.9461, 249.5270,  19.5097,  45.6413],
#         [195.7388, 102.3731,  33.6150,  80.2894]])
# xywhn: tensor([[0.7025, 0.6450, 0.1984, 0.4416],
#         [0.0465, 0.5060, 0.0901, 0.1942],
#         [0.5521, 0.5898, 0.1569, 0.3438],
#         [0.4287, 0.6145, 0.1557, 0.3414],
#         [0.7641, 0.1332, 0.1389, 0.2589],
#         [0.3030, 0.6191, 0.1499, 0.3149],
#         [0.1281, 0.4999, 0.0869, 0.1842],
#         [0.3467, 0.4874, 0.0610, 0.0891],
#         [0.6117, 0.1999, 0.1050, 0.1568]])
# xyxy: tensor([[193.0609, 217.1865, 256.5392, 443.3064],
#         [  0.4675, 209.3769,  29.2972, 308.7932],
#         [151.5806, 213.9790, 201.7845, 389.9804],
#         [112.2772, 227.1969, 162.0986, 402.0090],
#         [222.2959,   1.9268, 266.7584, 134.4605],
#         [ 72.9844, 236.3877, 120.9473, 397.6114],
#         [ 27.0940, 208.7887,  54.9175, 303.1080],
#         [101.1912, 226.7063, 120.7009, 272.3477],
#         [178.9313,  62.2284, 212.5463, 142.5178]])
# xyxyn: tensor([[0.6033, 0.4242, 0.8017, 0.8658],
#         [0.0015, 0.4089, 0.0916, 0.6031],
#         [0.4737, 0.4179, 0.6306, 0.7617],
#         [0.3509, 0.4437, 0.5066, 0.7852],
#         [0.6947, 0.0038, 0.8336, 0.2626],
#         [0.2281, 0.4617, 0.3780, 0.7766],
#         [0.0847, 0.4078, 0.1716, 0.5920],
#         [0.3162, 0.4428, 0.3772, 0.5319],
#         [0.5592, 0.1215, 0.6642, 0.2784]])
# image 1/1 C:\Work\Machine learning\Yolo\2.jpg: 640x416 7 persons, 2 traffic lights, 270.6ms
# Speed: 7.0ms preprocess, 270.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 416)

# %%
names= {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

# %%
# Define a video capture object 
vid = cv2.VideoCapture(0) 

while(True): 
    # Capture the video frame by frame 
    ret, frame = vid.read() 

    # Perform inference
    results = model(frame, stream=True,show=True)
    
    for result in results:
        # Draw bounding boxes on the frame
        print(result.boxes)
        for *box, conf, cls in result.boxes.xyxy:
            #label = f'{result.names[int(cls)]}: {conf:.2f}'
            print(result)
            # frame = cv2.rectangle(frame, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), (255,0,0), 2)
            # frame = cv2.putText(frame, "label", (int(box[0]), int(box[1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)

        # Display the resulting frame 
        cv2.imshow('frame', frame) 
    
        # Quitting button
        if cv2.waitKey(1) & 0xFF == ord('q'): 
            break

# Release the cap object 
vid.release() 
# Destroy all the windows 
cv2.destroyAllWindows()
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5708])
# data: tensor([[1.0285e+02, 1.7417e+02, 6.3261e+02, 4.7963e+02, 5.7081e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[367.7281, 326.9023, 529.7610, 305.4651]])
# xywhn: tensor([[0.5746, 0.6810, 0.8278, 0.6364]])
# xyxy: tensor([[102.8477, 174.1698, 632.6086, 479.6349]])
# xyxyn: tensor([[0.1607, 0.3629, 0.9885, 0.9992]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 50,  95, 107],
#         [ 45,  97, 107],
#         [ 43, 100, 109],
#         ...,
#         [163, 197, 220],
#         [165, 196, 221],
#         [166, 196, 221]],
#
#        [[ 52,  95, 107],
#         [ 48,  97, 107],
#         [ 46,  99, 107],
#         ...,
#         [163, 197, 220],
#         [165, 196, 221],
#         [166, 196, 221]],
#
#        [[ 55,  97, 104],
#         [ 51,  97, 104],
#         [ 49,  98, 104],
#         ...,
#         [163, 197, 220],
#         [165, 196, 221],
#         [166, 196, 221]],
#
#        ...,
#
#        [[ 34,  51,  26],
#         [ 36,  52,  26],
#         [ 36,  51,  25],
#         ...,
#         [ 64,  76,  94],
#         [ 69,  79,  96],
#         [ 69,  79,  96]],
#
#        [[ 36,  50,  26],
#         [ 37,  52,  26],
#         [ 37,  52,  26],
#         ...,
#         [ 56,  73,  91],
#         [ 61,  75,  94],
#         [ 61,  75,  94]],
#
#        [[ 33,  49,  25],
#         [ 32,  50,  25],
#         [ 33,  49,  25],
#         ...,
#         [ 49,  72,  88],
#         [ 52,  73,  92],
#         [ 55,  75,  94]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 8.992433547973633, 'inference': 123.5201358795166, 'postprocess': 2.000570297241211}
# 0: 480x640 1 person, 123.5ms
# Speed: 9.0ms preprocess, 123.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8140])
# data: tensor([[ 89.7172, 168.6153, 638.9171, 479.4760,   0.8140,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[364.3172, 324.0456, 549.1999, 310.8607]])
# xywhn: tensor([[0.5692, 0.6751, 0.8581, 0.6476]])
# xyxy: tensor([[ 89.7172, 168.6153, 638.9171, 479.4760]])
# xyxyn: tensor([[0.1402, 0.3513, 0.9983, 0.9989]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 69,  93, 109],
#         [ 73,  95, 110],
#         [ 73,  95, 109],
#         ...,
#         [168, 199, 226],
#         [160, 197, 224],
#         [158, 196, 222]],
#
#        [[ 70,  94, 110],
#         [ 70,  94, 110],
#         [ 71,  95, 111],
#         ...,
#         [165, 200, 224],
#         [160, 200, 224],
#         [157, 198, 222]],
#
#        [[ 72,  94, 110],
#         [ 72,  93, 111],
#         [ 72,  93, 112],
#         ...,
#         [164, 200, 223],
#         [159, 200, 221],
#         [159, 200, 221]],
#
#        ...,
#
#        [[ 27,  50,  20],
#         [ 29,  51,  22],
#         [ 32,  51,  25],
#         ...,
#         [ 76,  87, 127],
#         [ 80,  87, 125],
#         [ 76,  83, 121]],
#
#        [[ 25,  50,  20],
#         [ 27,  50,  21],
#         [ 30,  50,  23],
#         ...,
#         [ 67,  80, 120],
#         [ 75,  85, 122],
#         [ 77,  86, 123]],
#
#        [[ 25,  47,  18],
#         [ 26,  47,  19],
#         [ 28,  47,  23],
#         ...,
#         [ 62,  75, 116],
#         [ 68,  77, 117],
#         [ 71,  79, 119]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 33.540964126586914, 'inference': 176.5143871307373, 'postprocess': 1.0006427764892578}
# 0: 480x640 1 person, 176.5ms
# Speed: 33.5ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8087])
# data: tensor([[ 79.2776, 152.2392, 638.6873, 479.5095,   0.8087,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[358.9824, 315.8744, 559.4097, 327.2703]])
# xywhn: tensor([[0.5609, 0.6581, 0.8741, 0.6818]])
# xyxy: tensor([[ 79.2776, 152.2392, 638.6873, 479.5095]])
# xyxyn: tensor([[0.1239, 0.3172, 0.9979, 0.9990]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 46,  98, 109],
#         [ 50,  96, 109],
#         [ 55,  95, 110],
#         ...,
#         [160, 197, 221],
#         [163, 196, 221],
#         [162, 195, 219]],
#
#        [[ 49, 100, 107],
#         [ 53,  98, 107],
#         [ 59,  97, 109],
#         ...,
#         [164, 195, 219],
#         [166, 195, 219],
#         [165, 194, 218]],
#
#        [[ 50,  99, 106],
#         [ 55,  98, 106],
#         [ 61,  97, 107],
#         ...,
#         [166, 192, 216],
#         [166, 193, 215],
#         [165, 192, 214]],
#
#        ...,
#
#        [[ 25,  45,  27],
#         [ 32,  45,  29],
#         [ 40,  45,  31],
#         ...,
#         [ 63,  65,  93],
#         [ 63,  68,  95],
#         [ 67,  73,  99]],
#
#        [[ 27,  45,  27],
#         [ 32,  44,  28],
#         [ 40,  45,  31],
#         ...,
#         [ 59,  66,  93],
#         [ 61,  69,  93],
#         [ 62,  70,  94]],
#
#        [[ 26,  43,  28],
#         [ 31,  43,  27],
#         [ 39,  45,  28],
#         ...,
#         [ 56,  67,  90],
#         [ 56,  67,  89],
#         [ 56,  67,  89]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 7.002592086791992, 'inference': 156.0344696044922, 'postprocess': 5.021333694458008}
# 0: 480x640 1 person, 156.0ms
# Speed: 7.0ms preprocess, 156.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5950])
# data: tensor([[9.0984e+01, 1.3034e+02, 6.4000e+02, 4.7937e+02, 5.9504e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[365.4920, 304.8519, 549.0160, 349.0301]])
# xywhn: tensor([[0.5711, 0.6351, 0.8578, 0.7271]])
# xyxy: tensor([[ 90.9840, 130.3369, 640.0000, 479.3670]])
# xyxyn: tensor([[0.1422, 0.2715, 1.0000, 0.9987]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 68,  95, 106],
#         [ 62,  96, 106],
#         [ 55,  96, 106],
#         ...,
#         [162, 197, 215],
#         [161, 196, 213],
#         [159, 193, 210]],
#
#        [[ 69,  97, 106],
#         [ 65,  98, 107],
#         [ 59,  98, 106],
#         ...,
#         [165, 194, 212],
#         [165, 193, 211],
#         [163, 190, 208]],
#
#        [[ 71,  97, 106],
#         [ 70,  98, 107],
#         [ 66,  98, 107],
#         ...,
#         [170, 188, 207],
#         [170, 188, 207],
#         [166, 185, 204]],
#
#        ...,
#
#        [[ 30,  45,  30],
#         [ 30,  47,  30],
#         [ 29,  47,  28],
#         ...,
#         [ 48,  60,  76],
#         [ 49,  60,  82],
#         [ 49,  60,  83]],
#
#        [[ 28,  46,  28],
#         [ 29,  46,  27],
#         [ 30,  46,  26],
#         ...,
#         [ 47,  58,  75],
#         [ 49,  58,  80],
#         [ 50,  59,  81]],
#
#        [[ 27,  42,  25],
#         [ 28,  42,  25],
#         [ 29,  42,  25],
#         ...,
#         [ 48,  59,  71],
#         [ 49,  59,  76],
#         [ 50,  60,  78]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 3.0019283294677734, 'inference': 164.0467643737793, 'postprocess': 1.0001659393310547}
# 0: 480x640 1 person, 164.0ms
# Speed: 3.0ms preprocess, 164.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7214])
# data: tensor([[ 85.3691, 134.9005, 637.7120, 479.4881,   0.7214,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[361.5406, 307.1943, 552.3429, 344.5875]])
# xywhn: tensor([[0.5649, 0.6400, 0.8630, 0.7179]])
# xyxy: tensor([[ 85.3691, 134.9005, 637.7120, 479.4881]])
# xyxyn: tensor([[0.1334, 0.2810, 0.9964, 0.9989]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 63,  96, 109],
#         [ 56,  97, 108],
#         [ 50,  98, 107],
#         ...,
#         [172, 191, 219],
#         [173, 190, 218],
#         [174, 190, 218]],
#
#        [[ 63,  96, 111],
#         [ 58,  95, 109],
#         [ 55,  96, 108],
#         ...,
#         [170, 191, 213],
#         [170, 191, 209],
#         [170, 191, 209]],
#
#        [[ 63,  96, 111],
#         [ 61,  95, 109],
#         [ 62,  95, 108],
#         ...,
#         [165, 190, 208],
#         [161, 190, 203],
#         [159, 188, 201]],
#
#        ...,
#
#        [[ 42,  47,  26],
#         [ 42,  45,  27],
#         [ 42,  43,  29],
#         ...,
#         [ 38,  65,  76],
#         [ 38,  64,  78],
#         [ 36,  63,  77]],
#
#        [[ 34,  44,  22],
#         [ 34,  42,  24],
#         [ 34,  40,  25],
#         ...,
#         [ 42,  63,  73],
#         [ 42,  61,  75],
#         [ 41,  60,  75]],
#
#        [[ 27,  41,  19],
#         [ 26,  39,  19],
#         [ 27,  38,  21],
#         ...,
#         [ 47,  60,  71],
#         [ 50,  58,  73],
#         [ 48,  55,  71]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 3.0012130737304688, 'inference': 166.08238220214844, 'postprocess': 2.9938220977783203}
# 0: 480x640 1 person, 166.1ms
# Speed: 3.0ms preprocess, 166.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6372])
# data: tensor([[ 72.0877, 142.8218, 631.4467, 479.6564,   0.6372,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[351.7672, 311.2391, 559.3590, 336.8345]])
# xywhn: tensor([[0.5496, 0.6484, 0.8740, 0.7017]])
# xyxy: tensor([[ 72.0877, 142.8218, 631.4467, 479.6564]])
# xyxyn: tensor([[0.1126, 0.2975, 0.9866, 0.9993]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 79,  93, 108],
#         [ 72,  95, 110],
#         [ 62,  95, 110],
#         ...,
#         [177, 194, 218],
#         [176, 193, 216],
#         [174, 192, 215]],
#
#        [[ 76,  95, 109],
#         [ 71,  97, 111],
#         [ 63,  96, 111],
#         ...,
#         [175, 193, 216],
#         [172, 189, 215],
#         [171, 188, 214]],
#
#        [[ 75,  97, 109],
#         [ 71,  98, 110],
#         [ 65,  96, 109],
#         ...,
#         [170, 188, 215],
#         [167, 184, 210],
#         [166, 183, 209]],
#
#        ...,
#
#        [[ 32,  44,  34],
#         [ 32,  45,  34],
#         [ 29,  46,  33],
#         ...,
#         [ 51,  56,  75],
#         [ 54,  57,  75],
#         [ 54,  57,  75]],
#
#        [[ 30,  43,  35],
#         [ 29,  43,  36],
#         [ 27,  42,  34],
#         ...,
#         [ 52,  56,  74],
#         [ 56,  57,  75],
#         [ 57,  57,  75]],
#
#        [[ 27,  39,  34],
#         [ 26,  38,  33],
#         [ 24,  37,  31],
#         ...,
#         [ 51,  56,  74],
#         [ 56,  57,  75],
#         [ 58,  58,  76]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 5.000829696655273, 'inference': 201.10583305358887, 'postprocess': 2.0012855529785156}
# 0: 480x640 1 person, 201.1ms
# Speed: 5.0ms preprocess, 201.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7612])
# data: tensor([[ 88.8451, 136.8867, 626.0074, 479.5097,   0.7612,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[357.4262, 308.1982, 537.1623, 342.6230]])
# xywhn: tensor([[0.5585, 0.6421, 0.8393, 0.7138]])
# xyxy: tensor([[ 88.8451, 136.8867, 626.0074, 479.5097]])
# xyxyn: tensor([[0.1388, 0.2852, 0.9781, 0.9990]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 71,  95, 109],
#         [ 72,  94, 109],
#         [ 74,  93, 110],
#         ...,
#         [164, 195, 219],
#         [164, 193, 215],
#         [163, 192, 214]],
#
#        [[ 71,  95, 109],
#         [ 74,  95, 110],
#         [ 76,  95, 111],
#         ...,
#         [164, 191, 217],
#         [164, 190, 215],
#         [163, 189, 214]],
#
#        [[ 71,  95, 109],
#         [ 72,  95, 109],
#         [ 75,  96, 110],
#         ...,
#         [161, 184, 212],
#         [160, 183, 211],
#         [160, 183, 211]],
#
#        ...,
#
#        [[ 26,  44,  34],
#         [ 22,  45,  29],
#         [ 22,  47,  25],
#         ...,
#         [ 56,  60,  74],
#         [ 60,  61,  75],
#         [ 60,  61,  75]],
#
#        [[ 25,  42,  27],
#         [ 21,  41,  20],
#         [ 21,  43,  16],
#         ...,
#         [ 58,  62,  69],
#         [ 62,  63,  69],
#         [ 62,  63,  69]],
#
#        [[ 29,  42,  23],
#         [ 25,  40,  16],
#         [ 25,  41,  12],
#         ...,
#         [ 58,  62,  66],
#         [ 61,  62,  66],
#         [ 62,  63,  68]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 5.997419357299805, 'inference': 176.04756355285645, 'postprocess': 1.0004043579101562}
# 0: 480x640 1 person, 176.0ms
# Speed: 6.0ms preprocess, 176.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7686])
# data: tensor([[ 89.4578, 145.8552, 637.6874, 479.4282,   0.7686,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[363.5726, 312.6417, 548.2296, 333.5730]])
# xywhn: tensor([[0.5681, 0.6513, 0.8566, 0.6949]])
# xyxy: tensor([[ 89.4578, 145.8552, 637.6874, 479.4282]])
# xyxyn: tensor([[0.1398, 0.3039, 0.9964, 0.9988]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 57,  96, 111],
#         [ 57,  94, 113],
#         [ 57,  93, 115],
#         ...,
#         [163, 196, 216],
#         [165, 196, 211],
#         [164, 195, 209]],
#
#        [[ 63,  96, 109],
#         [ 63,  94, 112],
#         [ 63,  92, 114],
#         ...,
#         [165, 193, 216],
#         [166, 191, 211],
#         [165, 190, 210]],
#
#        [[ 69,  96, 109],
#         [ 73,  95, 112],
#         [ 74,  92, 113],
#         ...,
#         [165, 189, 213],
#         [166, 188, 211],
#         [165, 186, 209]],
#
#        ...,
#
#        [[ 33,  45,  33],
#         [ 36,  46,  30],
#         [ 39,  45,  26],
#         ...,
#         [ 48,  65,  67],
#         [ 48,  63,  68],
#         [ 48,  63,  68]],
#
#        [[ 31,  43,  31],
#         [ 33,  43,  26],
#         [ 36,  43,  24],
#         ...,
#         [ 43,  62,  63],
#         [ 45,  60,  63],
#         [ 47,  62,  65]],
#
#        [[ 29,  41,  28],
#         [ 29,  37,  23],
#         [ 34,  38,  21],
#         ...,
#         [ 40,  60,  60],
#         [ 45,  60,  61],
#         [ 47,  63,  64]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 2.999544143676758, 'inference': 186.06138229370117, 'postprocess': 1.9888877868652344}
# 0: 480x640 1 person, 186.1ms
# Speed: 3.0ms preprocess, 186.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7025])
# data: tensor([[ 83.6390, 141.8355, 638.9713, 479.2363,   0.7025,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[361.3052, 310.5359, 555.3323, 337.4009]])
# xywhn: tensor([[0.5645, 0.6469, 0.8677, 0.7029]])
# xyxy: tensor([[ 83.6390, 141.8355, 638.9713, 479.2363]])
# xyxyn: tensor([[0.1307, 0.2955, 0.9984, 0.9984]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 86,  93, 111],
#         [ 76,  95, 109],
#         [ 65,  97, 107],
#         ...,
#         [162, 193, 220],
#         [163, 192, 224],
#         [163, 192, 224]],
#
#        [[ 86,  93, 111],
#         [ 78,  94, 110],
#         [ 69,  96, 109],
#         ...,
#         [164, 193, 219],
#         [166, 191, 221],
#         [165, 190, 220]],
#
#        [[ 84,  93, 113],
#         [ 80,  96, 111],
#         [ 75,  97, 109],
#         ...,
#         [166, 192, 217],
#         [167, 191, 216],
#         [167, 191, 216]],
#
#        ...,
#
#        [[ 42,  48,  34],
#         [ 45,  45,  34],
#         [ 48,  43,  35],
#         ...,
#         [ 55,  60,  69],
#         [ 58,  62,  64],
#         [ 58,  62,  63]],
#
#        [[ 39,  47,  32],
#         [ 42,  45,  33],
#         [ 46,  44,  35],
#         ...,
#         [ 54,  59,  69],
#         [ 56,  60,  62],
#         [ 57,  61,  62]],
#
#        [[ 36,  46,  31],
#         [ 39,  44,  30],
#         [ 43,  44,  30],
#         ...,
#         [ 52,  60,  70],
#         [ 52,  60,  64],
#         [ 51,  59,  62]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 9.998798370361328, 'inference': 236.61470413208008, 'postprocess': 3.000974655151367}
# 0: 480x640 1 person, 236.6ms
# Speed: 10.0ms preprocess, 236.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7197])
# data: tensor([[ 71.7513, 132.0970, 636.1708, 479.5997,   0.7197,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[353.9611, 305.8484, 564.4194, 347.5026]])
# xywhn: tensor([[0.5531, 0.6372, 0.8819, 0.7240]])
# xyxy: tensor([[ 71.7513, 132.0970, 636.1708, 479.5997]])
# xyxyn: tensor([[0.1121, 0.2752, 0.9940, 0.9992]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 48,  98, 109],
#         [ 43,  99, 107],
#         [ 40, 100, 104],
#         ...,
#         [162, 197, 214],
#         [163, 196, 211],
#         [162, 195, 210]],
#
#        [[ 47,  97, 108],
#         [ 44,  99, 106],
#         [ 42, 100, 104],
#         ...,
#         [163, 194, 212],
#         [164, 195, 210],
#         [162, 192, 207]],
#
#        [[ 51,  97, 106],
#         [ 47,  97, 105],
#         [ 44,  97, 103],
#         ...,
#         [160, 192, 210],
#         [160, 190, 208],
#         [158, 188, 206]],
#
#        ...,
#
#        [[ 48,  49,  31],
#         [ 42,  47,  29],
#         [ 39,  48,  29],
#         ...,
#         [ 51,  62,  59],
#         [ 49,  62,  65],
#         [ 51,  64,  68]],
#
#        [[ 46,  46,  28],
#         [ 41,  45,  28],
#         [ 37,  45,  28],
#         ...,
#         [ 51,  62,  59],
#         [ 48,  61,  62],
#         [ 50,  64,  65]],
#
#        [[ 45,  41,  28],
#         [ 40,  40,  26],
#         [ 37,  41,  25],
#         ...,
#         [ 52,  63,  62],
#         [ 49,  62,  64],
#         [ 50,  64,  65]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 5.001544952392578, 'inference': 193.1297779083252, 'postprocess': 1.9998550415039062}
# 0: 480x640 1 person, 193.1ms
# Speed: 5.0ms preprocess, 193.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7308])
# data: tensor([[ 85.6375, 128.4053, 638.2954, 479.4766,   0.7308,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[361.9664, 303.9409, 552.6580, 351.0713]])
# xywhn: tensor([[0.5656, 0.6332, 0.8635, 0.7314]])
# xyxy: tensor([[ 85.6375, 128.4053, 638.2954, 479.4766]])
# xyxyn: tensor([[0.1338, 0.2675, 0.9973, 0.9989]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 78,  95, 107],
#         [ 78,  95, 109],
#         [ 76,  93, 110],
#         ...,
#         [173, 192, 220],
#         [174, 191, 217],
#         [175, 191, 217]],
#
#        [[ 79,  93, 108],
#         [ 78,  93, 109],
#         [ 76,  93, 110],
#         ...,
#         [172, 190, 216],
#         [171, 188, 212],
#         [171, 188, 212]],
#
#        [[ 79,  93, 108],
#         [ 77,  93, 109],
#         [ 73,  92, 109],
#         ...,
#         [170, 184, 209],
#         [171, 183, 207],
#         [170, 182, 206]],
#
#        ...,
#
#        [[ 32,  46,  25],
#         [ 31,  46,  26],
#         [ 33,  48,  29],
#         ...,
#         [ 54,  63,  65],
#         [ 50,  63,  68],
#         [ 50,  62,  69]],
#
#        [[ 30,  43,  26],
#         [ 28,  44,  27],
#         [ 27,  47,  29],
#         ...,
#         [ 51,  62,  59],
#         [ 47,  63,  64],
#         [ 45,  61,  63]],
#
#        [[ 23,  40,  27],
#         [ 22,  40,  27],
#         [ 24,  43,  29],
#         ...,
#         [ 51,  61,  58],
#         [ 46,  59,  60],
#         [ 44,  58,  59]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 2.992391586303711, 'inference': 175.59361457824707, 'postprocess': 1.9981861114501953}
# 0: 480x640 1 person, 175.6ms
# Speed: 3.0ms preprocess, 175.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6441])
# data: tensor([[ 72.2977, 135.3954, 615.4421, 479.7167,   0.6441,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[343.8699, 307.5560, 543.1444, 344.3213]])
# xywhn: tensor([[0.5373, 0.6407, 0.8487, 0.7173]])
# xyxy: tensor([[ 72.2977, 135.3954, 615.4421, 479.7167]])
# xyxyn: tensor([[0.1130, 0.2821, 0.9616, 0.9994]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 53,  96, 108],
#         [ 56,  97, 110],
#         [ 59,  96, 111],
#         ...,
#         [168, 195, 213],
#         [166, 194, 212],
#         [166, 194, 212]],
#
#        [[ 54,  97, 109],
#         [ 57,  98, 111],
#         [ 60,  98, 110],
#         ...,
#         [166, 194, 213],
#         [166, 193, 214],
#         [165, 192, 212]],
#
#        [[ 57,  96, 111],
#         [ 61,  98, 111],
#         [ 64,  97, 110],
#         ...,
#         [164, 192, 213],
#         [164, 190, 213],
#         [163, 189, 212]],
#
#        ...,
#
#        [[ 36,  48,  35],
#         [ 34,  48,  35],
#         [ 32,  49,  34],
#         ...,
#         [ 45,  64,  77],
#         [ 46,  63,  78],
#         [ 45,  62,  77]],
#
#        [[ 35,  47,  34],
#         [ 33,  47,  33],
#         [ 30,  48,  32],
#         ...,
#         [ 42,  62,  71],
#         [ 43,  60,  72],
#         [ 44,  61,  74]],
#
#        [[ 32,  44,  32],
#         [ 31,  45,  30],
#         [ 30,  46,  28],
#         ...,
#         [ 44,  62,  68],
#         [ 43,  58,  68],
#         [ 43,  58,  69]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 2.001523971557617, 'inference': 187.880277633667, 'postprocess': 1.0008811950683594}
# 0: 480x640 1 person, 187.9ms
# Speed: 2.0ms preprocess, 187.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7188])
# data: tensor([[ 75.9388, 128.0734, 617.0721, 479.7549,   0.7188,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[346.5054, 303.9142, 541.1333, 351.6815]])
# xywhn: tensor([[0.5414, 0.6332, 0.8455, 0.7327]])
# xyxy: tensor([[ 75.9388, 128.0734, 617.0721, 479.7549]])
# xyxyn: tensor([[0.1187, 0.2668, 0.9642, 0.9995]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 58,  94, 109],
#         [ 58,  93, 110],
#         [ 57,  95, 112],
#         ...,
#         [175, 195, 217],
#         [171, 193, 216],
#         [170, 192, 215]],
#
#        [[ 65,  96, 111],
#         [ 63,  95, 112],
#         [ 60,  94, 112],
#         ...,
#         [170, 193, 214],
#         [167, 192, 212],
#         [167, 192, 212]],
#
#        [[ 70,  97, 110],
#         [ 69,  97, 111],
#         [ 65,  96, 111],
#         ...,
#         [165, 189, 213],
#         [163, 190, 210],
#         [162, 190, 210]],
#
#        ...,
#
#        [[ 46,  46,  28],
#         [ 44,  46,  28],
#         [ 41,  45,  26],
#         ...,
#         [ 43,  60,  64],
#         [ 47,  61,  69],
#         [ 48,  62,  70]],
#
#        [[ 43,  45,  25],
#         [ 42,  45,  25],
#         [ 41,  46,  25],
#         ...,
#         [ 43,  59,  61],
#         [ 48,  60,  66],
#         [ 49,  61,  67]],
#
#        [[ 40,  45,  22],
#         [ 40,  45,  22],
#         [ 40,  44,  23],
#         ...,
#         [ 45,  60,  62],
#         [ 48,  60,  66],
#         [ 49,  61,  67]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 4.011631011962891, 'inference': 174.04961585998535, 'postprocess': 3.998279571533203}
# 0: 480x640 1 person, 174.0ms
# Speed: 4.0ms preprocess, 174.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7373])
# data: tensor([[ 63.1798, 139.6800, 636.6537, 479.6505,   0.7373,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[349.9167, 309.6652, 573.4739, 339.9705]])
# xywhn: tensor([[0.5467, 0.6451, 0.8961, 0.7083]])
# xyxy: tensor([[ 63.1798, 139.6800, 636.6537, 479.6505]])
# xyxyn: tensor([[0.0987, 0.2910, 0.9948, 0.9993]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 80,  93, 115],
#         [ 73,  91, 112],
#         [ 71,  91, 112],
#         ...,
#         [170, 192, 222],
#         [168, 191, 221],
#         [167, 190, 220]],
#
#        [[ 74,  97, 115],
#         [ 68,  93, 114],
#         [ 67,  91, 114],
#         ...,
#         [173, 187, 216],
#         [174, 186, 214],
#         [173, 185, 213]],
#
#        [[ 73,  99, 114],
#         [ 68,  94, 114],
#         [ 66,  93, 115],
#         ...,
#         [175, 179, 209],
#         [176, 178, 207],
#         [176, 178, 207]],
#
#        ...,
#
#        [[ 33,  49,  20],
#         [ 30,  48,  18],
#         [ 29,  50,  19],
#         ...,
#         [ 63,  59,  58],
#         [ 68,  61,  64],
#         [ 68,  60,  64]],
#
#        [[ 28,  48,  19],
#         [ 27,  47,  14],
#         [ 28,  48,  12],
#         ...,
#         [ 59,  61,  60],
#         [ 63,  60,  62],
#         [ 64,  61,  64]],
#
#        [[ 26,  46,  17],
#         [ 25,  44,  12],
#         [ 24,  44,   8],
#         ...,
#         [ 54,  60,  59],
#         [ 58,  61,  59],
#         [ 60,  62,  60]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 2.001047134399414, 'inference': 187.089204788208, 'postprocess': 2.985239028930664}
# 0: 480x640 1 person, 187.1ms
# Speed: 2.0ms preprocess, 187.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7146])
# data: tensor([[ 76.6549, 149.0707, 589.7312, 479.6978,   0.7146,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[333.1931, 314.3843, 513.0763, 330.6271]])
# xywhn: tensor([[0.5206, 0.6550, 0.8017, 0.6888]])
# xyxy: tensor([[ 76.6549, 149.0707, 589.7312, 479.6978]])
# xyxyn: tensor([[0.1198, 0.3106, 0.9215, 0.9994]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 43,  98, 104],
#         [ 51,  98, 108],
#         [ 59,  96, 111],
#         ...,
#         [164, 194, 213],
#         [166, 194, 212],
#         [166, 194, 212]],
#
#        [[ 43,  98, 106],
#         [ 51,  98, 109],
#         [ 59,  96, 111],
#         ...,
#         [163, 190, 210],
#         [163, 188, 209],
#         [163, 187, 208]],
#
#        [[ 47,  97, 108],
#         [ 53,  97, 110],
#         [ 59,  96, 111],
#         ...,
#         [166, 185, 209],
#         [165, 181, 210],
#         [163, 179, 208]],
#
#        ...,
#
#        [[ 35,  48,  31],
#         [ 32,  46,  27],
#         [ 31,  45,  25],
#         ...,
#         [ 51,  61,  63],
#         [ 48,  60,  66],
#         [ 47,  60,  66]],
#
#        [[ 28,  43,  26],
#         [ 29,  43,  25],
#         [ 29,  42,  23],
#         ...,
#         [ 51,  64,  65],
#         [ 47,  62,  65],
#         [ 45,  61,  64]],
#
#        [[ 23,  39,  19],
#         [ 22,  38,  18],
#         [ 22,  38,  18],
#         ...,
#         [ 49,  63,  62],
#         [ 47,  63,  64],
#         [ 46,  62,  62]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 2.99835205078125, 'inference': 185.96386909484863, 'postprocess': 1.9984245300292969}
# 0: 480x640 1 person, 186.0ms
# Speed: 3.0ms preprocess, 186.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7996])
# data: tensor([[ 75.9763, 143.6899, 624.4667, 479.7213,   0.7996,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[350.2215, 311.7056, 548.4904, 336.0314]])
# xywhn: tensor([[0.5472, 0.6494, 0.8570, 0.7001]])
# xyxy: tensor([[ 75.9763, 143.6899, 624.4667, 479.7213]])
# xyxyn: tensor([[0.1187, 0.2994, 0.9757, 0.9994]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
#         [ 54,  63,  55],
#         [ 54,  63,  55]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 2.9990673065185547, 'inference': 191.03598594665527, 'postprocess': 3.000020980834961}
# 0: 480x640 1 person, 191.0ms
# Speed: 3.0ms preprocess, 191.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6931])
# data: tensor([[ 84.5756, 121.9940, 636.2581, 479.4575,   0.6931,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[360.4168, 300.7258, 551.6824, 357.4635]])
# xywhn: tensor([[0.5632, 0.6265, 0.8620, 0.7447]])
# xyxy: tensor([[ 84.5756, 121.9940, 636.2581, 479.4575]])
# xyxyn: tensor([[0.1321, 0.2542, 0.9942, 0.9989]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 59,  97, 107],
#         [ 62,  97, 107],
#         [ 67,  96, 107],
#         ...,
#         [162, 186, 212],
#         [161, 184, 214],
#         [159, 181, 212]],
#
#        [[ 57,  96, 108],
#         [ 61,  97, 108],
#         [ 66,  98, 109],
#         ...,
#         [161, 182, 205],
#         [161, 180, 205],
#         [160, 179, 205]],
#
#        [[ 58,  94, 109],
#         [ 60,  96, 110],
#         [ 62,  98, 110],
#         ...,
#         [160, 178, 202],
#         [161, 177, 203],
#         [161, 177, 203]],
#
#        ...,
#
#        [[ 29,  48,  26],
#         [ 29,  49,  23],
#         [ 29,  50,  20],
#         ...,
#         [ 62,  65,  63],
#         [ 61,  67,  62],
#         [ 60,  66,  60]],
#
#        [[ 30,  47,  23],
#         [ 30,  49,  22],
#         [ 29,  50,  20],
#         ...,
#         [ 62,  63,  62],
#         [ 61,  64,  59],
#         [ 59,  63,  58]],
#
#        [[ 34,  48,  19],
#         [ 31,  48,  19],
#         [ 29,  50,  20],
#         ...,
#         [ 62,  63,  62],
#         [ 61,  64,  59],
#         [ 59,  63,  58]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 3.0083656311035156, 'inference': 181.03694915771484, 'postprocess': 2.000570297241211}
# 0: 480x640 1 person, 181.0ms
# Speed: 3.0ms preprocess, 181.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5906])
# data: tensor([[8.1849e+01, 1.1824e+02, 6.3581e+02, 4.7945e+02, 5.9058e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[358.8315, 298.8474, 553.9655, 361.2141]])
# xywhn: tensor([[0.5607, 0.6226, 0.8656, 0.7525]])
# xyxy: tensor([[ 81.8488, 118.2403, 635.8142, 479.4544]])
# xyxyn: tensor([[0.1279, 0.2463, 0.9935, 0.9989]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 56,  93, 110],
#         [ 55,  93, 112],
#         [ 54,  93, 112],
#         ...,
#         [168, 188, 209],
#         [170, 185, 207],
#         [169, 184, 205]],
#
#        [[ 59,  96, 113],
#         [ 58,  94, 113],
#         [ 58,  93, 112],
#         ...,
#         [168, 183, 202],
#         [170, 181, 203],
#         [171, 181, 203]],
#
#        [[ 62,  97, 114],
#         [ 60,  94, 114],
#         [ 61,  92, 114],
#         ...,
#         [167, 181, 199],
#         [169, 181, 200],
#         [169, 181, 200]],
#
#        ...,
#
#        [[ 42,  44,  35],
#         [ 43,  46,  35],
#         [ 44,  47,  34],
#         ...,
#         [ 49,  63,  56],
#         [ 52,  63,  55],
#         [ 53,  63,  55]],
#
#        [[ 44,  44,  35],
#         [ 47,  47,  34],
#         [ 48,  49,  31],
#         ...,
#         [ 49,  62,  56],
#         [ 50,  61,  53],
#         [ 51,  62,  54]],
#
#        [[ 43,  45,  36],
#         [ 45,  47,  34],
#         [ 48,  49,  31],
#         ...,
#         [ 49,  61,  57],
#         [ 50,  60,  55],
#         [ 51,  61,  56]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 3.0019283294677734, 'inference': 179.5213222503662, 'postprocess': 1.9998550415039062}
# 0: 480x640 1 person, 179.5ms
# Speed: 3.0ms preprocess, 179.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7115])
# data: tensor([[ 80.4801, 125.8499, 624.3143, 479.4395,   0.7115,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[352.3972, 302.6447, 543.8342, 353.5896]])
# xywhn: tensor([[0.5506, 0.6305, 0.8497, 0.7366]])
# xyxy: tensor([[ 80.4801, 125.8499, 624.3143, 479.4395]])
# xyxyn: tensor([[0.1258, 0.2622, 0.9755, 0.9988]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 69,  93, 109],
#         [ 68,  94, 109],
#         [ 66,  95, 108],
#         ...,
#         [162, 192, 209],
#         [163, 189, 207],
#         [163, 188, 206]],
#
#        [[ 70,  97, 110],
#         [ 68,  97, 109],
#         [ 65,  97, 107],
#         ...,
#         [160, 185, 209],
#         [163, 182, 208],
#         [163, 181, 207]],
#
#        [[ 70,  97, 109],
#         [ 67,  98, 108],
#         [ 64,  98, 109],
#         ...,
#         [160, 179, 208],
#         [162, 177, 208],
#         [160, 175, 206]],
#
#        ...,
#
#        [[ 44,  47,  35],
#         [ 40,  44,  34],
#         [ 39,  46,  36],
#         ...,
#         [ 55,  64,  55],
#         [ 58,  63,  58],
#         [ 59,  64,  60]],
#
#        [[ 40,  48,  34],
#         [ 37,  44,  32],
#         [ 38,  44,  35],
#         ...,
#         [ 53,  64,  57],
#         [ 55,  63,  58],
#         [ 56,  63,  58]],
#
#        [[ 38,  49,  32],
#         [ 36,  44,  31],
#         [ 38,  44,  35],
#         ...,
#         [ 51,  64,  57],
#         [ 53,  64,  58],
#         [ 52,  62,  57]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 2.9990673065185547, 'inference': 181.32400512695312, 'postprocess': 1.9998550415039062}
# 0: 480x640 1 person, 181.3ms
# Speed: 3.0ms preprocess, 181.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7363])
# data: tensor([[ 79.9540, 123.0342, 638.3256, 479.4057,   0.7363,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[359.1398, 301.2200, 558.3715, 356.3715]])
# xywhn: tensor([[0.5612, 0.6275, 0.8725, 0.7424]])
# xyxy: tensor([[ 79.9540, 123.0342, 638.3256, 479.4057]])
# xyxyn: tensor([[0.1249, 0.2563, 0.9974, 0.9988]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 55,  97, 104],
#         [ 57,  99, 107],
#         [ 58,  99, 107],
#         ...,
#         [161, 187, 213],
#         [158, 186, 213],
#         [157, 185, 212]],
#
#        [[ 60,  96, 106],
#         [ 61,  96, 107],
#         [ 62,  95, 108],
#         ...,
#         [155, 182, 211],
#         [151, 181, 210],
#         [150, 180, 209]],
#
#        [[ 64,  95, 108],
#         [ 67,  94, 109],
#         [ 70,  94, 110],
#         ...,
#         [153, 178, 208],
#         [153, 178, 208],
#         [152, 177, 207]],
#
#        ...,
#
#        [[ 41,  48,  27],
#         [ 40,  51,  28],
#         [ 37,  52,  28],
#         ...,
#         [ 45,  68,  61],
#         [ 49,  72,  60],
#         [ 48,  71,  59]],
#
#        [[ 39,  49,  25],
#         [ 35,  49,  26],
#         [ 34,  50,  28],
#         ...,
#         [ 43,  66,  58],
#         [ 46,  67,  56],
#         [ 47,  68,  57]],
#
#        [[ 39,  49,  23],
#         [ 35,  50,  24],
#         [ 34,  51,  26],
#         ...,
#         [ 46,  64,  58],
#         [ 48,  63,  55],
#         [ 48,  63,  55]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 4.003286361694336, 'inference': 186.0651969909668, 'postprocess': 2.001523971557617}
# 0: 480x640 1 person, 186.1ms
# Speed: 4.0ms preprocess, 186.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6585])
# data: tensor([[ 71.4658, 111.2890, 638.2878, 479.3972,   0.6585,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[354.8768, 295.3431, 566.8220, 368.1082]])
# xywhn: tensor([[0.5545, 0.6153, 0.8857, 0.7669]])
# xyxy: tensor([[ 71.4658, 111.2890, 638.2878, 479.3972]])
# xyxyn: tensor([[0.1117, 0.2319, 0.9973, 0.9987]])
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 73,  95, 111],
#         [ 74,  96, 113],
#         [ 73,  94, 113],
#         ...,
#         [166, 191, 204],
#         [167, 188, 204],
#         [165, 185, 202]],
#
#        [[ 73,  95, 111],
#         [ 73,  95, 112],
#         [ 73,  94, 113],
#         ...,
#         [165, 188, 203],
#         [163, 184, 202],
#         [160, 180, 199]],
#
#        [[ 72,  94, 110],
#         [ 72,  93, 111],
#         [ 72,  93, 112],
#         ...,
#         [161, 182, 200],
#         [161, 178, 200],
#         [160, 177, 199]],
#
#        ...,
#
#        [[ 44,  46,  37],
#         [ 42,  48,  33],
#         [ 41,  51,  29],
#         ...,
#         [ 53,  61,  63],
#         [ 60,  61,  65],
#         [ 61,  62,  67]],
#
#        [[ 45,  48,  38],
#         [ 43,  49,  35],
#         [ 41,  50,  31],
#         ...,
#         [ 51,  60,  64],
#         [ 56,  59,  66],
#         [ 59,  62,  68]],
#
#        [[ 43,  48,  38],
#         [ 42,  49,  36],
#         [ 39,  47,  31],
#         ...,
#         [ 51,  61,  63],
#         [ 56,  59,  66],
#         [ 58,  60,  67]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: None
# speed: {'preprocess': 2.511262893676758, 'inference': 180.52148818969727, 'postprocess': 2.0003318786621094}
# 0: 480x640 1 person, 180.5ms
# Speed: 2.5ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
